# %%
from google.colab import drive
drive.mount('/content/drive')

# !unzip "/content/drive/My Drive/data.zip" -d "/content"
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
#   inflating: /content/data/data/train/image_train/image_941622065_product_207151527.jpg
#   inflating: /content/data/data/train/image_train/image_941622067_product_207151563.jpg
#   inflating: /content/data/data/train/image_train/image_941622071_product_207151331.jpg
#   inflating: /content/data/data/train/image_train/image_941622073_product_207151492.jpg
#   inflating: /content/data/data/train/image_train/image_941622084_product_207151508.jpg
#   inflating: /content/data/data/train/image_train/image_941622086_product_207151543.jpg
#   inflating: /content/data/data/train/image_train/image_941622094_product_207151287.jpg
#   inflating: /content/data/data/train/image_train/image_941622096_product_207151567.jpg
#   inflating: /content/data/data/train/image_train/image_941622100_product_207151555.jpg
#   inflating: /content/data/data/train/image_train/image_941622102_product_207151329.jpg
#   inflating: /content/data/data/train/image_train/image_941622104_product_207151308.jpg
#   inflating: /content/data/data/train/image_train/image_941622113_product_207151291.jpg
#   inflating: /content/data/data/train/image_train/image_941622124_product_207151478.jpg
#   inflating: /content/data/data/train/image_train/image_941622130_product_207151336.jpg
#   inflating: /content/data/data/train/image_train/image_941622136_product_207151475.jpg
#   inflating: /content/data/data/train/image_train/image_941622138_product_207151518.jpg
#   inflating: /content/data/data/train/image_train/image_941622142_product_207151314.jpg
#   inflating: /content/data/data/train/image_train/image_941622146_product_207151281.jpg
#   inflating: /content/data/data/train/image_train/image_941622148_product_207151295.jpg
#   inflating: /content/data/data/train/image_train/image_941622150_product_207151503.jpg
#   inflating: /content/data/data/train/image_train/image_941622152_product_207151461.jpg
#   inflating: /content/data/data/train/image_train/image_941622154_product_207151335.jpg
#   inflating: /content/data/data/train/image_train/image_941622156_product_207151477.jpg
#   inflating: /content/data/data/train/image_train/image_941622170_product_207151491.jpg
#   inflating: /content/data/data/train/image_train/image_941622174_product_207151570.jpg
#   inflating: /content/data/data/train/image_train/image_941622181_product_207151297.jpg
#   inflating: /content/data/data/train/image_train/image_941622183_product_207151573.jpg
#   inflating: /content/data/data/train/image_train/image_941622187_product_207151529.jpg
#   inflating: /content/data/data/train/image_train/image_941622193_product_207151283.jpg
#   inflating: /content/data/data/train/image_train/image_941622195_product_207151506.jpg
#   inflating: /content/data/data/train/image_train/image_941622197_product_207151572.jpg
#   inflating: /content/data/data/train/image_train/image_941622199_product_207151317.jpg
#   inflating: /content/data/data/train/image_train/image_941622203_product_207151465.jpg
#   inflating: /content/data/data/train/image_train/image_941622208_product_207151541.jpg
#   inflating: /content/data/data/train/image_train/image_941622213_product_207151504.jpg
#   inflating: /content/data/data/train/image_train/image_941622215_product_207151299.jpg
#   inflating: /content/data/data/train/image_train/image_941622217_product_207151494.jpg
#   inflating: /content/data/data/train/image_train/image_941622220_product_207151322.jpg
#   inflating: /content/data/data/train/image_train/image_941622222_product_207151489.jpg
#   inflating: /content/data/data/train/image_train/image_941622232_product_207151528.jpg
#   inflating: /content/data/data/train/image_train/image_941622236_product_207151507.jpg
#   inflating: /content/data/data/train/image_train/image_941622238_product_207151309.jpg
#   inflating: /content/data/data/train/image_train/image_941622248_product_207151515.jpg
#   inflating: /content/data/data/train/image_train/image_941622252_product_207151530.jpg
#   inflating: /content/data/data/train/image_train/image_941622258_product_207151544.jpg
#   inflating: /content/data/data/train/image_train/image_941622263_product_207151290.jpg
#   inflating: /content/data/data/train/image_train/image_941622269_product_207151481.jpg
#   inflating: /content/data/data/train/image_train/image_941622272_product_207151553.jpg
#   inflating: /content/data/data/train/image_train/image_941622274_product_207151289.jpg
#   inflating: /content/data/data/train/image_train/image_941622279_product_207151536.jpg
#   inflating: /content/data/data/train/image_train/image_941622281_product_207151551.jpg
#   inflating: /content/data/data/train/image_train/image_941632465_product_207159785.jpg
#   inflating: /content/data/data/train/image_train/image_941634929_product_207159776.jpg
#   inflating: /content/data/data/train/image_train/image_941635457_product_207159381.jpg
#   inflating: /content/data/data/train/image_train/image_941642508_product_207170094.jpg
#   inflating: /content/data/data/train/image_train/image_941642512_product_207170102.jpg
#   inflating: /content/data/data/train/image_train/image_941642515_product_207170091.jpg
#   inflating: /content/data/data/train/image_train/image_941642522_product_207170105.jpg
#   inflating: /content/data/data/train/image_train/image_941642524_product_207170097.jpg
#   inflating: /content/data/data/train/image_train/image_941643039_product_207170092.jpg
#   inflating: /content/data/data/train/image_train/image_941643041_product_207170095.jpg
#   inflating: /content/data/data/train/image_train/image_941643043_product_207170098.jpg
#   inflating: /content/data/data/train/image_train/image_941643048_product_207170089.jpg
#   inflating: /content/data/data/train/image_train/image_941643065_product_207170090.jpg
#   inflating: /content/data/data/train/image_train/image_941653250_product_207208979.jpg
#   inflating: /content/data/data/train/image_train/image_941657086_product_207008677.jpg
#   inflating: /content/data/data/train/image_train/image_941657121_product_207119770.jpg
#   inflating: /content/data/data/train/image_train/image_941658827_product_206671196.jpg
#   inflating: /content/data/data/train/image_train/image_941666614_product_207129086.jpg
#   inflating: /content/data/data/train/image_train/image_941672860_product_207072607.jpg
#   inflating: /content/data/data/train/image_train/image_941676206_product_207258056.jpg
#   inflating: /content/data/data/train/image_train/image_941676210_product_207257918.jpg
#   inflating: /content/data/data/train/image_train/image_941676214_product_207258066.jpg
#   inflating: /content/data/data/train/image_train/image_941676216_product_207257878.jpg
#   inflating: /content/data/data/train/image_train/image_941676640_product_207257949.jpg
#   inflating: /content/data/data/train/image_train/image_941676652_product_207257880.jpg
#   inflating: /content/data/data/train/image_train/image_941676654_product_207257877.jpg
#   inflating: /content/data/data/train/image_train/image_941676660_product_207257895.jpg
#   inflating: /content/data/data/train/image_train/image_941676662_product_207258080.jpg
#   inflating: /content/data/data/train/image_train/image_941676676_product_207196204.jpg
#   inflating: /content/data/data/train/image_train/image_941676692_product_207257936.jpg
#   inflating: /content/data/data/train/image_train/image_941676702_product_207196245.jpg
#   inflating: /content/data/data/train/image_train/image_941676704_product_207258055.jpg
#   inflating: /content/data/data/train/image_train/image_941676712_product_207258062.jpg
#   inflating: /content/data/data/train/image_train/image_941677134_product_207257922.jpg
#   inflating: /content/data/data/train/image_train/image_941677136_product_207196227.jpg
#   inflating: /content/data/data/train/image_train/image_941677140_product_207257921.jpg
#   inflating: /content/data/data/train/image_train/image_941677144_product_207196182.jpg
#   inflating: /content/data/data/train/image_train/image_941677156_product_207257892.jpg
#   inflating: /content/data/data/train/image_train/image_941677170_product_207196206.jpg
#   inflating: /content/data/data/train/image_train/image_941677178_product_207258159.jpg
#   inflating: /content/data/data/train/image_train/image_941677998_product_207196178.jpg
#   inflating: /content/data/data/train/image_train/image_941678002_product_207196180.jpg
#   inflating: /content/data/data/train/image_train/image_941678009_product_207196192.jpg
#   inflating: /content/data/data/train/image_train/image_941678014_product_207257914.jpg
#   inflating: /content/data/data/train/image_train/image_941678016_product_207196196.jpg
#   inflating: /content/data/data/train/image_train/image_941678018_product_207257905.jpg
#   inflating: /content/data/data/train/image_train/image_941678309_product_207196248.jpg
#   inflating: /content/data/data/train/image_train/image_941678319_product_207257891.jpg
#   inflating: /content/data/data/train/image_train/image_941678322_product_207257916.jpg
#   inflating: /content/data/data/train/image_train/image_941678324_product_207196229.jpg
#   inflating: /content/data/data/train/image_train/image_941678337_product_207196201.jpg
#   inflating: /content/data/data/train/image_train/image_941678351_product_207258158.jpg
#   inflating: /content/data/data/train/image_train/image_941678361_product_207257911.jpg
#   inflating: /content/data/data/train/image_train/image_941678375_product_207257886.jpg
#   inflating: /content/data/data/train/image_train/image_941678382_product_207196239.jpg
#   inflating: /content/data/data/train/image_train/image_941678386_product_207258199.jpg
#   inflating: /content/data/data/train/image_train/image_941678397_product_207258060.jpg
#   inflating: /content/data/data/train/image_train/image_941678411_product_207257917.jpg
#   inflating: /content/data/data/train/image_train/image_941678415_product_207258161.jpg
#   inflating: /content/data/data/train/image_train/image_941678422_product_207196235.jpg
#   inflating: /content/data/data/train/image_train/image_941678447_product_207258117.jpg
#   inflating: /content/data/data/train/image_train/image_941678458_product_207196199.jpg
#   inflating: /content/data/data/train/image_train/image_941678462_product_207258050.jpg
#   inflating: /content/data/data/train/image_train/image_941678490_product_207257894.jpg
#   inflating: /content/data/data/train/image_train/image_941678534_product_207258064.jpg
#   inflating: /content/data/data/train/image_train/image_941678536_product_207196230.jpg
#   inflating: /content/data/data/train/image_train/image_941678540_product_207258156.jpg
#   inflating: /content/data/data/train/image_train/image_941678546_product_207257909.jpg
#   inflating: /content/data/data/train/image_train/image_941678550_product_207258063.jpg
#   inflating: /content/data/data/train/image_train/image_941678552_product_207257912.jpg
#   inflating: /content/data/data/train/image_train/image_941678554_product_207257881.jpg
#   inflating: /content/data/data/train/image_train/image_941678558_product_207196205.jpg
#   inflating: /content/data/data/train/image_train/image_941678560_product_207258162.jpg
#   inflating: /content/data/data/train/image_train/image_941678562_product_207258079.jpg
#   inflating: /content/data/data/train/image_train/image_941678582_product_207196218.jpg
#   inflating: /content/data/data/train/image_train/image_941678588_product_207257898.jpg
#   inflating: /content/data/data/train/image_train/image_941678590_product_207258051.jpg
#   inflating: /content/data/data/train/image_train/image_941678600_product_207258102.jpg
#   inflating: /content/data/data/train/image_train/image_941678606_product_207257896.jpg
#   inflating: /content/data/data/train/image_train/image_941678615_product_207257910.jpg
#   inflating: /content/data/data/train/image_train/image_941678626_product_207196162.jpg
#   inflating: /content/data/data/train/image_train/image_941678631_product_207257943.jpg
#   inflating: /content/data/data/train/image_train/image_941678641_product_207196247.jpg
#   inflating: /content/data/data/train/image_train/image_941678666_product_207257920.jpg
#   inflating: /content/data/data/train/image_train/image_941678684_product_207196225.jpg
#   inflating: /content/data/data/train/image_train/image_941678688_product_207257889.jpg
#   inflating: /content/data/data/train/image_train/image_941678692_product_207257930.jpg
#   inflating: /content/data/data/train/image_train/image_941678701_product_207258057.jpg
#   inflating: /content/data/data/train/image_train/image_941678711_product_207258154.jpg
#   inflating: /content/data/data/train/image_train/image_941678713_product_207196194.jpg
#   inflating: /content/data/data/train/image_train/image_941678715_product_207196193.jpg
#   inflating: /content/data/data/train/image_train/image_941678719_product_207196198.jpg
#   inflating: /content/data/data/train/image_train/image_941678721_product_207257897.jpg
#   inflating: /content/data/data/train/image_train/image_941678723_product_207257919.jpg
#   inflating: /content/data/data/train/image_train/image_941678727_product_207257948.jpg
#   inflating: /content/data/data/train/image_train/image_941678734_product_207258067.jpg
#   inflating: /content/data/data/train/image_train/image_941678738_product_207257913.jpg
#   inflating: /content/data/data/train/image_train/image_941678740_product_207196195.jpg
#   inflating: /content/data/data/train/image_train/image_941678742_product_207196200.jpg
#   inflating: /content/data/data/train/image_train/image_941678744_product_207257883.jpg
#   inflating: /content/data/data/train/image_train/image_941678756_product_207258103.jpg
#   inflating: /content/data/data/train/image_train/image_941678758_product_207196181.jpg
#   inflating: /content/data/data/train/image_train/image_941678760_product_207196226.jpg
#   inflating: /content/data/data/train/image_train/image_941678768_product_207196190.jpg
#   inflating: /content/data/data/train/image_train/image_941678776_product_207258087.jpg
#   inflating: /content/data/data/train/image_train/image_941678778_product_207196231.jpg
#   inflating: /content/data/data/train/image_train/image_941678782_product_207257907.jpg
#   inflating: /content/data/data/train/image_train/image_941678793_product_207196224.jpg
#   inflating: /content/data/data/train/image_train/image_941678799_product_207258150.jpg
#   inflating: /content/data/data/train/image_train/image_941678801_product_207196179.jpg
#   inflating: /content/data/data/train/image_train/image_941678807_product_207258061.jpg
#   inflating: /content/data/data/train/image_train/image_941678818_product_207257887.jpg
#   inflating: /content/data/data/train/image_train/image_941678848_product_207257923.jpg
#   inflating: /content/data/data/train/image_train/image_941678850_product_207257906.jpg
#   inflating: /content/data/data/train/image_train/image_941678852_product_207258076.jpg
#   inflating: /content/data/data/train/image_train/image_941678856_product_207257904.jpg
#   inflating: /content/data/data/train/image_train/image_941678870_product_207257942.jpg
#   inflating: /content/data/data/train/image_train/image_941678887_product_207258101.jpg
#   inflating: /content/data/data/train/image_train/image_941678889_product_207258059.jpg
#   inflating: /content/data/data/train/image_train/image_941678895_product_207257899.jpg
#   inflating: /content/data/data/train/image_train/image_941678907_product_207258168.jpg
#   inflating: /content/data/data/train/image_train/image_941678909_product_207257935.jpg
#   inflating: /content/data/data/train/image_train/image_941678925_product_207257938.jpg
#   inflating: /content/data/data/train/image_train/image_941678927_product_207258052.jpg
#   inflating: /content/data/data/train/image_train/image_941679033_product_207258065.jpg
#   inflating: /content/data/data/train/image_train/image_941680860_product_201700578.jpg
#   inflating: /content/data/data/train/image_train/image_941693567_product_207287172.jpg
#   inflating: /content/data/data/train/image_train/image_941693581_product_207287166.jpg
#   inflating: /content/data/data/train/image_train/image_941693586_product_207287179.jpg
#   inflating: /content/data/data/train/image_train/image_941693588_product_207287176.jpg
#   inflating: /content/data/data/train/image_train/image_941693594_product_207287178.jpg
#   inflating: /content/data/data/train/image_train/image_941693596_product_207287181.jpg
#   inflating: /content/data/data/train/image_train/image_941693603_product_207287191.jpg
#   inflating: /content/data/data/train/image_train/image_941693605_product_207287183.jpg
#   inflating: /content/data/data/train/image_train/image_941693634_product_207287177.jpg
#   inflating: /content/data/data/train/image_train/image_941693644_product_207287175.jpg
#   inflating: /content/data/data/train/image_train/image_941693648_product_207287170.jpg
#   inflating: /content/data/data/train/image_train/image_941693650_product_207287188.jpg
#   inflating: /content/data/data/train/image_train/image_941693658_product_207287189.jpg
#   inflating: /content/data/data/train/image_train/image_941693674_product_207287174.jpg
#   inflating: /content/data/data/train/image_train/image_941693676_product_207287171.jpg
#   inflating: /content/data/data/train/image_train/image_941693678_product_207287169.jpg
#   inflating: /content/data/data/train/image_train/image_941693682_product_207287196.jpg
#   inflating: /content/data/data/train/image_train/image_941693684_product_207287165.jpg
#   inflating: /content/data/data/train/image_train/image_941693686_product_207287184.jpg
#   inflating: /content/data/data/train/image_train/image_941693688_product_207287173.jpg
#   inflating: /content/data/data/train/image_train/image_941693689_product_207286233.jpg
#   inflating: /content/data/data/train/image_train/image_941693695_product_207287182.jpg
#   inflating: /content/data/data/train/image_train/image_941693697_product_207287190.jpg
#   inflating: /content/data/data/train/image_train/image_941693699_product_207287187.jpg
#   inflating: /content/data/data/train/image_train/image_941696681_product_207288971.jpg
#   inflating: /content/data/data/train/image_train/image_941697515_product_207289359.jpg
#   inflating: /content/data/data/train/image_train/image_941698026_product_207289304.jpg
#   inflating: /content/data/data/train/image_train/image_941702968_product_207292686.jpg
#   inflating: /content/data/data/train/image_train/image_941709913_product_207304894.jpg
#   inflating: /content/data/data/train/image_train/image_941710141_product_5064576.jpg
#   inflating: /content/data/data/train/image_train/image_941710215_product_207304671.jpg
#   inflating: /content/data/data/train/image_train/image_941710306_product_207304864.jpg
#   inflating: /content/data/data/train/image_train/image_941710580_product_190099239.jpg
#   inflating: /content/data/data/train/image_train/image_941710645_product_207304977.jpg
#   inflating: /content/data/data/train/image_train/image_941710864_product_80378291.jpg
#   inflating: /content/data/data/train/image_train/image_941710868_product_207304902.jpg
#   inflating: /content/data/data/train/image_train/image_941719274_product_207310349.jpg
#   inflating: /content/data/data/train/image_train/image_941721653_product_48598697.jpg
#   inflating: /content/data/data/train/image_train/image_941749808_product_207249756.jpg
#   inflating: /content/data/data/train/image_train/image_941749826_product_207249762.jpg
#   inflating: /content/data/data/train/image_train/image_941752952_product_207249771.jpg
#   inflating: /content/data/data/train/image_train/image_941755156_product_207263631.jpg
#   inflating: /content/data/data/train/image_train/image_941760727_product_207114514.jpg
#   inflating: /content/data/data/train/image_train/image_941766532_product_207404801.jpg
#   inflating: /content/data/data/train/image_train/image_941801254_product_207481762.jpg
#   inflating: /content/data/data/train/image_train/image_941839136_product_207542568.jpg
#   inflating: /content/data/data/train/image_train/image_941855135_product_207163830.jpg
#   inflating: /content/data/data/train/image_train/image_941870372_product_207132325.jpg
#   inflating: /content/data/data/train/image_train/image_941872757_product_174843392.jpg
#   inflating: /content/data/data/train/image_train/image_941874086_product_207639272.jpg
#   inflating: /content/data/data/train/image_train/image_941874094_product_207639280.jpg
#   inflating: /content/data/data/train/image_train/image_941874108_product_207639264.jpg
#   inflating: /content/data/data/train/image_train/image_941883982_product_207543180.jpg
#   inflating: /content/data/data/train/image_train/image_941883990_product_207555699.jpg
#   inflating: /content/data/data/train/image_train/image_941884473_product_70060718.jpg
#   inflating: /content/data/data/train/image_train/image_941884476_product_207548491.jpg
#   inflating: /content/data/data/train/image_train/image_941885425_product_207632469.jpg
#   inflating: /content/data/data/train/image_train/image_941885531_product_207626492.jpg
#   inflating: /content/data/data/train/image_train/image_941902501_product_207703914.jpg
#   inflating: /content/data/data/train/image_train/image_941906257_product_207704542.jpg
#   inflating: /content/data/data/train/image_train/image_941993992_product_207785600.jpg
#   inflating: /content/data/data/train/image_train/image_942027813_product_207914057.jpg
#   inflating: /content/data/data/train/image_train/image_942033629_product_207962482.jpg
#   inflating: /content/data/data/train/image_train/image_942034991_product_207977444.jpg
#   inflating: /content/data/data/train/image_train/image_942063538_product_208026590.jpg
#   inflating: /content/data/data/train/image_train/image_942069842_product_208038176.jpg
#   inflating: /content/data/data/train/image_train/image_942083617_product_208082265.jpg
#   inflating: /content/data/data/train/image_train/image_942085827_product_207489274.jpg
#   inflating: /content/data/data/train/image_train/image_942086395_product_158982305.jpg
#   inflating: /content/data/data/train/image_train/image_942087006_product_138732065.jpg
#   inflating: /content/data/data/train/image_train/image_942099182_product_207680953.jpg
#   inflating: /content/data/data/train/image_train/image_942210828_product_208194729.jpg
#   inflating: /content/data/data/train/image_train/image_9456930_product_992281.jpg
#   inflating: /content/data/data/train/image_train/image_946228894_product_3507566.jpg
#   inflating: /content/data/data/train/image_train/image_946230965_product_207673978.jpg
#   inflating: /content/data/data/train/image_train/image_946230975_product_207672178.jpg
#   inflating: /content/data/data/train/image_train/image_946230990_product_207691159.jpg
#   inflating: /content/data/data/train/image_train/image_946230992_product_207691173.jpg
#   inflating: /content/data/data/train/image_train/image_946231005_product_207696723.jpg
#   inflating: /content/data/data/train/image_train/image_946231149_product_208072197.jpg
#   inflating: /content/data/data/train/image_train/image_946232026_product_185194885.jpg
#   inflating: /content/data/data/train/image_train/image_946233952_product_208307868.jpg
#   inflating: /content/data/data/train/image_train/image_946250445_product_208333647.jpg
#   inflating: /content/data/data/train/image_train/image_946263224_product_49582852.jpg
#   inflating: /content/data/data/train/image_train/image_946264883_product_53929449.jpg
#   inflating: /content/data/data/train/image_train/image_946265426_product_55043513.jpg
#   inflating: /content/data/data/train/image_train/image_946267926_product_57229958.jpg
#   inflating: /content/data/data/train/image_train/image_946267956_product_56381004.jpg
#   inflating: /content/data/data/train/image_train/image_946269034_product_56442955.jpg
#   inflating: /content/data/data/train/image_train/image_946269195_product_57233146.jpg
#   inflating: /content/data/data/train/image_train/image_946271032_product_57542403.jpg
#   inflating: /content/data/data/train/image_train/image_946271075_product_208363010.jpg
#   inflating: /content/data/data/train/image_train/image_946272484_product_57158581.jpg
#   inflating: /content/data/data/train/image_train/image_946272855_product_59728602.jpg
#   inflating: /content/data/data/train/image_train/image_946272865_product_59839586.jpg
#   inflating: /content/data/data/train/image_train/image_946273069_product_16378945.jpg
#   inflating: /content/data/data/train/image_train/image_946273142_product_60347031.jpg
#   inflating: /content/data/data/train/image_train/image_946273165_product_208364111.jpg
#   inflating: /content/data/data/train/image_train/image_946273252_product_60415950.jpg
#   inflating: /content/data/data/train/image_train/image_946273520_product_88366751.jpg
#   inflating: /content/data/data/train/image_train/image_946273912_product_62995885.jpg
#   inflating: /content/data/data/train/image_train/image_946274320_product_96501221.jpg
#   inflating: /content/data/data/train/image_train/image_946280133_product_75245524.jpg
#   inflating: /content/data/data/train/image_train/image_946297679_product_92813202.jpg
#   inflating: /content/data/data/train/image_train/image_946298451_product_77635459.jpg
#   inflating: /content/data/data/train/image_train/image_946299004_product_71670136.jpg
#   inflating: /content/data/data/train/image_train/image_946301932_product_208381222.jpg
#   inflating: /content/data/data/train/image_train/image_946302448_product_208381920.jpg
#   inflating: /content/data/data/train/image_train/image_946307097_product_208384576.jpg
#   inflating: /content/data/data/train/image_train/image_946314613_product_208306711.jpg
#   inflating: /content/data/data/train/image_train/image_946328775_product_63958052.jpg
#   inflating: /content/data/data/train/image_train/image_946376404_product_207892663.jpg
#   inflating: /content/data/data/train/image_train/image_946424001_product_196888225.jpg
#   inflating: /content/data/data/train/image_train/image_946448511_product_208539341.jpg
#   inflating: /content/data/data/train/image_train/image_946468414_product_85356803.jpg
#   inflating: /content/data/data/train/image_train/image_946470989_product_205707244.jpg
#   inflating: /content/data/data/train/image_train/image_946489233_product_205951947.jpg
#   inflating: /content/data/data/train/image_train/image_946508640_product_205823670.jpg
#   inflating: /content/data/data/train/image_train/image_946517531_product_179274912.jpg
#   inflating: /content/data/data/train/image_train/image_946518577_product_196547987.jpg
#   inflating: /content/data/data/train/image_train/image_946530575_product_203948672.jpg
#   inflating: /content/data/data/train/image_train/image_946534904_product_191848447.jpg
#   inflating: /content/data/data/train/image_train/image_946553062_product_199083268.jpg
#   inflating: /content/data/data/train/image_train/image_946555389_product_148244303.jpg
#   inflating: /content/data/data/train/image_train/image_946556640_product_205557086.jpg
#   inflating: /content/data/data/train/image_train/image_946557204_product_205560139.jpg
#   inflating: /content/data/data/train/image_train/image_946563724_product_180145096.jpg
#   inflating: /content/data/data/train/image_train/image_946580688_product_204251288.jpg
#   inflating: /content/data/data/train/image_train/image_946584131_product_206461609.jpg
#   inflating: /content/data/data/train/image_train/image_946589879_product_208035660.jpg
#   inflating: /content/data/data/train/image_train/image_946590676_product_208427217.jpg
#   inflating: /content/data/data/train/image_train/image_946638314_product_208617401.jpg
#   inflating: /content/data/data/train/image_train/image_946641178_product_189613830.jpg
#   inflating: /content/data/data/train/image_train/image_946685896_product_192442770.jpg
#   inflating: /content/data/data/train/image_train/image_946687253_product_161999894.jpg
#   inflating: /content/data/data/train/image_train/image_946687617_product_143446374.jpg
#   inflating: /content/data/data/train/image_train/image_946699126_product_208684132.jpg
#   inflating: /content/data/data/train/image_train/image_946699128_product_208684131.jpg
#   inflating: /content/data/data/train/image_train/image_946699871_product_208686943.jpg
#   inflating: /content/data/data/train/image_train/image_946699877_product_208686946.jpg
#   inflating: /content/data/data/train/image_train/image_946699880_product_208686945.jpg
#   inflating: /content/data/data/train/image_train/image_946699881_product_208686942.jpg
#   inflating: /content/data/data/train/image_train/image_946699882_product_208686939.jpg
#   inflating: /content/data/data/train/image_train/image_946702481_product_208697564.jpg
#   inflating: /content/data/data/train/image_train/image_946713999_product_208715308.jpg
#   inflating: /content/data/data/train/image_train/image_946714000_product_208715288.jpg
#   inflating: /content/data/data/train/image_train/image_946714001_product_208715297.jpg
#   inflating: /content/data/data/train/image_train/image_946714002_product_208715285.jpg
#   inflating: /content/data/data/train/image_train/image_946714003_product_208715282.jpg
#   inflating: /content/data/data/train/image_train/image_946714005_product_208715310.jpg
#   inflating: /content/data/data/train/image_train/image_946714006_product_208715296.jpg
#   inflating: /content/data/data/train/image_train/image_946714008_product_208715283.jpg
#   inflating: /content/data/data/train/image_train/image_946714009_product_208715304.jpg
#   inflating: /content/data/data/train/image_train/image_946714013_product_208715293.jpg
#   inflating: /content/data/data/train/image_train/image_946714015_product_208715292.jpg
#   inflating: /content/data/data/train/image_train/image_946714019_product_208715311.jpg
#   inflating: /content/data/data/train/image_train/image_946714020_product_208715300.jpg
#   inflating: /content/data/data/train/image_train/image_946714022_product_208715281.jpg
#   inflating: /content/data/data/train/image_train/image_946714023_product_208715291.jpg
#   inflating: /content/data/data/train/image_train/image_946714024_product_208715294.jpg
#   inflating: /content/data/data/train/image_train/image_946714026_product_208715303.jpg
#   inflating: /content/data/data/train/image_train/image_946714029_product_208715302.jpg
#   inflating: /content/data/data/train/image_train/image_946714530_product_208715298.jpg
#   inflating: /content/data/data/train/image_train/image_946714532_product_208715295.jpg
#   inflating: /content/data/data/train/image_train/image_946714533_product_208715307.jpg
#   inflating: /content/data/data/train/image_train/image_946714537_product_208715313.jpg
#   inflating: /content/data/data/train/image_train/image_946714538_product_208715284.jpg
#   inflating: /content/data/data/train/image_train/image_946714543_product_208715309.jpg
#   inflating: /content/data/data/train/image_train/image_946714544_product_208715289.jpg
#   inflating: /content/data/data/train/image_train/image_946721447_product_208735305.jpg
#   inflating: /content/data/data/train/image_train/image_946721739_product_208735386.jpg
#   inflating: /content/data/data/train/image_train/image_946830436_product_208827443.jpg
#   inflating: /content/data/data/train/image_train/image_946835695_product_208845661.jpg
#   inflating: /content/data/data/train/image_train/image_946841677_product_208730456.jpg
#   inflating: /content/data/data/train/image_train/image_946875975_product_208913691.jpg
#   inflating: /content/data/data/train/image_train/image_946881096_product_208929813.jpg
#   inflating: /content/data/data/train/image_train/image_946890176_product_208944973.jpg
#   inflating: /content/data/data/train/image_train/image_946911423_product_209034896.jpg
#   inflating: /content/data/data/train/image_train/image_946932405_product_209049661.jpg
#   inflating: /content/data/data/train/image_train/image_946944652_product_209067278.jpg
#   inflating: /content/data/data/train/image_train/image_947001157_product_209139076.jpg
#   inflating: /content/data/data/train/image_train/image_947012265_product_209166191.jpg
#   inflating: /content/data/data/train/image_train/image_947015172_product_209167679.jpg
#   inflating: /content/data/data/train/image_train/image_947022949_product_209182723.jpg
#   inflating: /content/data/data/train/image_train/image_947040701_product_208760997.jpg
#   inflating: /content/data/data/train/image_train/image_947063626_product_55046396.jpg
#   inflating: /content/data/data/train/image_train/image_947071214_product_46675181.jpg
#   inflating: /content/data/data/train/image_train/image_947080313_product_208977262.jpg
#   inflating: /content/data/data/train/image_train/image_947080319_product_208977272.jpg
#   inflating: /content/data/data/train/image_train/image_947128283_product_97662640.jpg
#   inflating: /content/data/data/train/image_train/image_947131876_product_209253278.jpg
#   inflating: /content/data/data/train/image_train/image_947132660_product_209253181.jpg
#   inflating: /content/data/data/train/image_train/image_947134671_product_209241716.jpg
#   inflating: /content/data/data/train/image_train/image_947147483_product_209252641.jpg
#   inflating: /content/data/data/train/image_train/image_947159032_product_124775699.jpg
#   inflating: /content/data/data/train/image_train/image_947184929_product_126618853.jpg
#   inflating: /content/data/data/train/image_train/image_947188622_product_209244791.jpg
#   inflating: /content/data/data/train/image_train/image_947188824_product_209342192.jpg
#   inflating: /content/data/data/train/image_train/image_947189019_product_209249191.jpg
#   inflating: /content/data/data/train/image_train/image_947189380_product_209026723.jpg
#   inflating: /content/data/data/train/image_train/image_947189381_product_209026716.jpg
#   inflating: /content/data/data/train/image_train/image_947189786_product_209342185.jpg
#   inflating: /content/data/data/train/image_train/image_947190002_product_208989628.jpg
#   inflating: /content/data/data/train/image_train/image_947191434_product_209153624.jpg
#   inflating: /content/data/data/train/image_train/image_947204280_product_208857287.jpg
#   inflating: /content/data/data/train/image_train/image_947206925_product_209370105.jpg
#   inflating: /content/data/data/train/image_train/image_947212849_product_209379792.jpg
#   inflating: /content/data/data/train/image_train/image_947227525_product_209412874.jpg
#   inflating: /content/data/data/train/image_train/image_947239430_product_209423751.jpg
#   inflating: /content/data/data/train/image_train/image_947336840_product_147373859.jpg
#   inflating: /content/data/data/train/image_train/image_947345043_product_209518714.jpg
#   inflating: /content/data/data/train/image_train/image_947351200_product_209068266.jpg
#   inflating: /content/data/data/train/image_train/image_947358221_product_209339122.jpg
#   inflating: /content/data/data/train/image_train/image_947411763_product_209671785.jpg
#   inflating: /content/data/data/train/image_train/image_947446256_product_209783732.jpg
#   inflating: /content/data/data/train/image_train/image_947459913_product_209824652.jpg
#   inflating: /content/data/data/train/image_train/image_947460234_product_209824752.jpg
#   inflating: /content/data/data/train/image_train/image_947460235_product_209824653.jpg
#   inflating: /content/data/data/train/image_train/image_947460239_product_209824754.jpg
#   inflating: /content/data/data/train/image_train/image_947460240_product_209824751.jpg
#   inflating: /content/data/data/train/image_train/image_947460243_product_209824756.jpg
#   inflating: /content/data/data/train/image_train/image_947460245_product_209824654.jpg
#   inflating: /content/data/data/train/image_train/image_947475134_product_209739021.jpg
#   inflating: /content/data/data/train/image_train/image_947482007_product_209743462.jpg
#   inflating: /content/data/data/train/image_train/image_947541075_product_204055375.jpg
#   inflating: /content/data/data/train/image_train/image_947549202_product_209925253.jpg
#   inflating: /content/data/data/train/image_train/image_947549484_product_209925478.jpg
#   inflating: /content/data/data/train/image_train/image_947562489_product_209955707.jpg
#   inflating: /content/data/data/train/image_train/image_947572566_product_155197977.jpg
#   inflating: /content/data/data/train/image_train/image_947613309_product_209689239.jpg
#   inflating: /content/data/data/train/image_train/image_947617717_product_181461745.jpg
#   inflating: /content/data/data/train/image_train/image_947620247_product_209806809.jpg
#   inflating: /content/data/data/train/image_train/image_947620276_product_209826796.jpg
#   inflating: /content/data/data/train/image_train/image_947711548_product_206216984.jpg
#   inflating: /content/data/data/train/image_train/image_947712263_product_210110708.jpg
#   inflating: /content/data/data/train/image_train/image_947731199_product_210138610.jpg
#   inflating: /content/data/data/train/image_train/image_947738747_product_210128578.jpg
#   inflating: /content/data/data/train/image_train/image_947746850_product_179668963.jpg
#   inflating: /content/data/data/train/image_train/image_947746907_product_116630865.jpg
#   inflating: /content/data/data/train/image_train/image_947749671_product_209896724.jpg
#   inflating: /content/data/data/train/image_train/image_947751326_product_99787050.jpg
#   inflating: /content/data/data/train/image_train/image_947764097_product_209606981.jpg
#   inflating: /content/data/data/train/image_train/image_947767534_product_209642981.jpg
#   inflating: /content/data/data/train/image_train/image_947767539_product_209695066.jpg
#   inflating: /content/data/data/train/image_train/image_947777598_product_210192148.jpg
#   inflating: /content/data/data/train/image_train/image_947784553_product_210194441.jpg
#   inflating: /content/data/data/train/image_train/image_947785080_product_210199304.jpg
#   inflating: /content/data/data/train/image_train/image_947791946_product_207286236.jpg
#   inflating: /content/data/data/train/image_train/image_947808711_product_210254068.jpg
#   inflating: /content/data/data/train/image_train/image_947812584_product_210152611.jpg
#   inflating: /content/data/data/train/image_train/image_947815052_product_210147526.jpg
#   inflating: /content/data/data/train/image_train/image_947819447_product_209895346.jpg
#   inflating: /content/data/data/train/image_train/image_947819500_product_209384409.jpg
#   inflating: /content/data/data/train/image_train/image_947819502_product_125805514.jpg
#   inflating: /content/data/data/train/image_train/image_947836642_product_210137847.jpg
#   inflating: /content/data/data/train/image_train/image_947873676_product_18045197.jpg
#   inflating: /content/data/data/train/image_train/image_947895852_product_210288815.jpg
#   inflating: /content/data/data/train/image_train/image_947905896_product_210335171.jpg
#   inflating: /content/data/data/train/image_train/image_947913222_product_210398931.jpg
#   inflating: /content/data/data/train/image_train/image_947921366_product_209976619.jpg
#   inflating: /content/data/data/train/image_train/image_947931175_product_210420667.jpg
#   inflating: /content/data/data/train/image_train/image_947941545_product_210426837.jpg
#   inflating: /content/data/data/train/image_train/image_947941608_product_210427214.jpg
#   inflating: /content/data/data/train/image_train/image_947947049_product_210414298.jpg
#   inflating: /content/data/data/train/image_train/image_947951184_product_210440554.jpg
#   inflating: /content/data/data/train/image_train/image_947959330_product_210452373.jpg
#   inflating: /content/data/data/train/image_train/image_947959434_product_210452699.jpg
#   inflating: /content/data/data/train/image_train/image_947988270_product_210513034.jpg
#   inflating: /content/data/data/train/image_train/image_947991778_product_210518459.jpg
#   inflating: /content/data/data/train/image_train/image_948000273_product_210533472.jpg
#   inflating: /content/data/data/train/image_train/image_948002879_product_210524132.jpg
#   inflating: /content/data/data/train/image_train/image_948014949_product_210557553.jpg
#   inflating: /content/data/data/train/image_train/image_948020671_product_210549791.jpg
#   inflating: /content/data/data/train/image_train/image_948021176_product_210584765.jpg
#   inflating: /content/data/data/train/image_train/image_948031750_product_183723318.jpg
#   inflating: /content/data/data/train/image_train/image_948065690_product_210693922.jpg
#   inflating: /content/data/data/train/image_train/image_948070991_product_210517047.jpg
#   inflating: /content/data/data/train/image_train/image_948071410_product_210483933.jpg
#   inflating: /content/data/data/train/image_train/image_948071559_product_210561835.jpg
#   inflating: /content/data/data/train/image_train/image_948077736_product_166187827.jpg
#   inflating: /content/data/data/train/image_train/image_948095138_product_210690956.jpg
#   inflating: /content/data/data/train/image_train/image_948102925_product_210765311.jpg
#   inflating: /content/data/data/train/image_train/image_948124730_product_210584974.jpg
#   inflating: /content/data/data/train/image_train/image_948124848_product_210694062.jpg
#   inflating: /content/data/data/train/image_train/image_948125087_product_210748215.jpg
#   inflating: /content/data/data/train/image_train/image_948147163_product_210323285.jpg
#   inflating: /content/data/data/train/image_train/image_948196892_product_210561779.jpg
#   inflating: /content/data/data/train/image_train/image_948200962_product_191515944.jpg
#   inflating: /content/data/data/train/image_train/image_948277018_product_210963717.jpg
#   inflating: /content/data/data/train/image_train/image_948317622_product_210988249.jpg
#   inflating: /content/data/data/train/image_train/image_948423127_product_210674425.jpg
#   inflating: /content/data/data/train/image_train/image_948457447_product_210850589.jpg
#   inflating: /content/data/data/train/image_train/image_948461618_product_210750215.jpg
#   inflating: /content/data/data/train/image_train/image_948471305_product_211079757.jpg
#   inflating: /content/data/data/train/image_train/image_948476842_product_211186162.jpg
#   inflating: /content/data/data/train/image_train/image_948476867_product_211186170.jpg
#   inflating: /content/data/data/train/image_train/image_948476880_product_211186175.jpg
#   inflating: /content/data/data/train/image_train/image_948494478_product_211207642.jpg
#   inflating: /content/data/data/train/image_train/image_948539936_product_211166080.jpg
#   inflating: /content/data/data/train/image_train/image_948539948_product_211266614.jpg
#   inflating: /content/data/data/train/image_train/image_948553168_product_211282555.jpg
#   inflating: /content/data/data/train/image_train/image_948553170_product_211282557.jpg
#   inflating: /content/data/data/train/image_train/image_948578415_product_211293526.jpg
#   inflating: /content/data/data/train/image_train/image_948579243_product_5680951.jpg
#   inflating: /content/data/data/train/image_train/image_948580134_product_53642875.jpg
#   inflating: /content/data/data/train/image_train/image_948580138_product_211299777.jpg
#   inflating: /content/data/data/train/image_train/image_948581076_product_211288387.jpg
#   inflating: /content/data/data/train/image_train/image_948587814_product_211342151.jpg
#   inflating: /content/data/data/train/image_train/image_948600218_product_211326201.jpg
#   inflating: /content/data/data/train/image_train/image_948605852_product_211325293.jpg
#   inflating: /content/data/data/train/image_train/image_948607058_product_211332197.jpg
#   inflating: /content/data/data/train/image_train/image_948608572_product_211334790.jpg
#   inflating: /content/data/data/train/image_train/image_948610852_product_194674281.jpg
#   inflating: /content/data/data/train/image_train/image_948646932_product_211355064.jpg
#   inflating: /content/data/data/train/image_train/image_948654382_product_211411401.jpg
#   inflating: /content/data/data/train/image_train/image_948664632_product_211309972.jpg
#   inflating: /content/data/data/train/image_train/image_948664718_product_211332574.jpg
#   inflating: /content/data/data/train/image_train/image_948679633_product_211397689.jpg
#   inflating: /content/data/data/train/image_train/image_948680705_product_211385713.jpg
#   inflating: /content/data/data/train/image_train/image_948682956_product_211398779.jpg
#   inflating: /content/data/data/train/image_train/image_948730706_product_211455711.jpg
#   inflating: /content/data/data/train/image_train/image_948730716_product_211455716.jpg
#   inflating: /content/data/data/train/image_train/image_949110757_product_211959637.jpg
#   inflating: /content/data/data/train/image_train/image_949120782_product_211963607.jpg
#   inflating: /content/data/data/train/image_train/image_949120784_product_211959636.jpg
#   inflating: /content/data/data/train/image_train/image_949216210_product_212100383.jpg
#   inflating: /content/data/data/train/image_train/image_949216969_product_212091332.jpg
#   inflating: /content/data/data/train/image_train/image_949254753_product_212176943.jpg
#   inflating: /content/data/data/train/image_train/image_949260904_product_212190754.jpg
#   inflating: /content/data/data/train/image_train/image_949260909_product_212190757.jpg
#   inflating: /content/data/data/train/image_train/image_949260911_product_212190755.jpg
#   inflating: /content/data/data/train/image_train/image_949260913_product_212190756.jpg
#   inflating: /content/data/data/train/image_train/image_949272377_product_211787644.jpg
#   inflating: /content/data/data/train/image_train/image_949293437_product_212218275.jpg
#   inflating: /content/data/data/train/image_train/image_949294388_product_212221284.jpg
#   inflating: /content/data/data/train/image_train/image_949304430_product_212230365.jpg
#   inflating: /content/data/data/train/image_train/image_949304463_product_212230370.jpg
#   inflating: /content/data/data/train/image_train/image_949320905_product_212253890.jpg
#   inflating: /content/data/data/train/image_train/image_949320909_product_212253903.jpg
#   inflating: /content/data/data/train/image_train/image_949320924_product_212253909.jpg
#   inflating: /content/data/data/train/image_train/image_949321013_product_212253877.jpg
#   inflating: /content/data/data/train/image_train/image_949321019_product_212253902.jpg
#   inflating: /content/data/data/train/image_train/image_949321021_product_212253872.jpg
#   inflating: /content/data/data/train/image_train/image_949321029_product_212253900.jpg
#   inflating: /content/data/data/train/image_train/image_949321030_product_212253883.jpg
#   inflating: /content/data/data/train/image_train/image_949321038_product_212253901.jpg
#   inflating: /content/data/data/train/image_train/image_949321044_product_212253881.jpg
#   inflating: /content/data/data/train/image_train/image_949370454_product_212091274.jpg
#   inflating: /content/data/data/train/image_train/image_949376304_product_211969641.jpg
#   inflating: /content/data/data/train/image_train/image_949378202_product_212075296.jpg
#   inflating: /content/data/data/train/image_train/image_949380961_product_212334999.jpg
#   inflating: /content/data/data/train/image_train/image_949382356_product_212343189.jpg
#   inflating: /content/data/data/train/image_train/image_949383355_product_212340857.jpg
#   inflating: /content/data/data/train/image_train/image_949383461_product_212342907.jpg
#   inflating: /content/data/data/train/image_train/image_949383508_product_212340856.jpg
# ...
#   inflating: /content/data/data/train/image_train/image_997153828_product_67641883.jpg
#   inflating: /content/data/data/train/image_train/image_997172758_product_328188055.jpg
#   inflating: /content/data/data/train/image_train/image_997177389_product_314654412.jpg
#   inflating: /content/data/data/train/image_train/image_997182740_product_320388594.jpg
#   inflating: /content/data/data/train/image_train/image_997184297_product_328788150.jpg
#   inflating: /content/data/data/train/image_train/image_997192676_product_210237073.jpg
#   inflating: /content/data/data/train/image_train/image_997223741_product_328044078.jpg
#   inflating: /content/data/data/train/image_train/image_997242353_product_86826922.jpg
#   inflating: /content/data/data/train/image_train/image_997276362_product_86419416.jpg
#   inflating: /content/data/data/train/image_train/image_997283332_product_209743530.jpg
#   inflating: /content/data/data/train/image_train/image_997293558_product_328119149.jpg
#   inflating: /content/data/data/train/image_train/image_997323780_product_86788227.jpg
#   inflating: /content/data/data/train/image_train/image_997330186_product_85589484.jpg
#   inflating: /content/data/data/train/image_train/image_997332749_product_93258101.jpg
#   inflating: /content/data/data/train/image_train/image_997335324_product_85446554.jpg
#   inflating: /content/data/data/train/image_train/image_997348898_product_53278963.jpg
#   inflating: /content/data/data/train/image_train/image_99735230_product_3132266.jpg
#   inflating: /content/data/data/train/image_train/image_997376916_product_127228877.jpg
#   inflating: /content/data/data/train/image_train/image_997384438_product_67911125.jpg
#   inflating: /content/data/data/train/image_train/image_997401153_product_86654550.jpg
#   inflating: /content/data/data/train/image_train/image_997419462_product_74529248.jpg
#   inflating: /content/data/data/train/image_train/image_997420262_product_86928409.jpg
#   inflating: /content/data/data/train/image_train/image_997441026_product_85372885.jpg
#   inflating: /content/data/data/train/image_train/image_997445352_product_318479643.jpg
#   inflating: /content/data/data/train/image_train/image_997456981_product_326180860.jpg
#   inflating: /content/data/data/train/image_train/image_997497701_product_18648935.jpg
#   inflating: /content/data/data/train/image_train/image_997504094_product_85429964.jpg
#   inflating: /content/data/data/train/image_train/image_997521696_product_52965419.jpg
#   inflating: /content/data/data/train/image_train/image_997531111_product_330239241.jpg
#   inflating: /content/data/data/train/image_train/image_997552764_product_330203999.jpg
#   inflating: /content/data/data/train/image_train/image_997562648_product_67739219.jpg
#   inflating: /content/data/data/train/image_train/image_997576384_product_67574428.jpg
#   inflating: /content/data/data/train/image_train/image_997587110_product_210668388.jpg
#   inflating: /content/data/data/train/image_train/image_997598726_product_77489810.jpg
#   inflating: /content/data/data/train/image_train/image_997602835_product_67312551.jpg
#   inflating: /content/data/data/train/image_train/image_997603929_product_98574272.jpg
#   inflating: /content/data/data/train/image_train/image_997614186_product_85913883.jpg
#   inflating: /content/data/data/train/image_train/image_997620858_product_86889335.jpg
#   inflating: /content/data/data/train/image_train/image_997623158_product_86422895.jpg
#   inflating: /content/data/data/train/image_train/image_997671167_product_331347559.jpg
#   inflating: /content/data/data/train/image_train/image_997671169_product_331347556.jpg
#   inflating: /content/data/data/train/image_train/image_997678552_product_93409902.jpg
#   inflating: /content/data/data/train/image_train/image_997679246_product_74457029.jpg
#   inflating: /content/data/data/train/image_train/image_997725435_product_86868357.jpg
#   inflating: /content/data/data/train/image_train/image_997725833_product_93643951.jpg
#   inflating: /content/data/data/train/image_train/image_997746788_product_86265418.jpg
#   inflating: /content/data/data/train/image_train/image_997749981_product_67462707.jpg
#   inflating: /content/data/data/train/image_train/image_997816663_product_86353138.jpg
#   inflating: /content/data/data/train/image_train/image_997831277_product_92360786.jpg
#   inflating: /content/data/data/train/image_train/image_997842131_product_150685670.jpg
#   inflating: /content/data/data/train/image_train/image_997858628_product_332155130.jpg
#   inflating: /content/data/data/train/image_train/image_997858830_product_332155013.jpg
#   inflating: /content/data/data/train/image_train/image_997859009_product_87398453.jpg
#   inflating: /content/data/data/train/image_train/image_997877716_product_332542372.jpg
#   inflating: /content/data/data/train/image_train/image_997885635_product_332557807.jpg
#   inflating: /content/data/data/train/image_train/image_997887917_product_332358881.jpg
#   inflating: /content/data/data/train/image_train/image_997903677_product_67824130.jpg
#   inflating: /content/data/data/train/image_train/image_997944942_product_332684635.jpg
#   inflating: /content/data/data/train/image_train/image_997946927_product_332686220.jpg
#   inflating: /content/data/data/train/image_train/image_997973033_product_67240245.jpg
#   inflating: /content/data/data/train/image_train/image_998007800_product_86657288.jpg
#   inflating: /content/data/data/train/image_train/image_998117168_product_331852564.jpg
#   inflating: /content/data/data/train/image_train/image_998133615_product_74534070.jpg
#   inflating: /content/data/data/train/image_train/image_998165034_product_67705452.jpg
#   inflating: /content/data/data/train/image_train/image_998176650_product_332311987.jpg
#   inflating: /content/data/data/train/image_train/image_998267625_product_334492445.jpg
#   inflating: /content/data/data/train/image_train/image_998279682_product_334563248.jpg
#   inflating: /content/data/data/train/image_train/image_998280599_product_334563014.jpg
#   inflating: /content/data/data/train/image_train/image_998280894_product_334562957.jpg
#   inflating: /content/data/data/train/image_train/image_998292977_product_334561837.jpg
#   inflating: /content/data/data/train/image_train/image_998293011_product_334562723.jpg
#   inflating: /content/data/data/train/image_train/image_998293303_product_334563088.jpg
#   inflating: /content/data/data/train/image_train/image_998293365_product_334561450.jpg
#   inflating: /content/data/data/train/image_train/image_998293381_product_334562483.jpg
#   inflating: /content/data/data/train/image_train/image_998293389_product_334561010.jpg
#   inflating: /content/data/data/train/image_train/image_998293504_product_334562897.jpg
#   inflating: /content/data/data/train/image_train/image_998304584_product_334561471.jpg
#   inflating: /content/data/data/train/image_train/image_998304667_product_334688491.jpg
#   inflating: /content/data/data/train/image_train/image_998305996_product_334562646.jpg
#   inflating: /content/data/data/train/image_train/image_998316908_product_87555116.jpg
#   inflating: /content/data/data/train/image_train/image_998318838_product_334560246.jpg
#   inflating: /content/data/data/train/image_train/image_998333910_product_334559843.jpg
#   inflating: /content/data/data/train/image_train/image_998334542_product_334563105.jpg
#   inflating: /content/data/data/train/image_train/image_998351717_product_334563422.jpg
#   inflating: /content/data/data/train/image_train/image_998363453_product_321453803.jpg
#   inflating: /content/data/data/train/image_train/image_998373974_product_334571319.jpg
#   inflating: /content/data/data/train/image_train/image_998391537_product_334572131.jpg
#   inflating: /content/data/data/train/image_train/image_998392311_product_334570772.jpg
#   inflating: /content/data/data/train/image_train/image_998392484_product_334564034.jpg
#   inflating: /content/data/data/train/image_train/image_998392842_product_334564726.jpg
#   inflating: /content/data/data/train/image_train/image_998403218_product_52963942.jpg
#   inflating: /content/data/data/train/image_train/image_998409078_product_334566565.jpg
#   inflating: /content/data/data/train/image_train/image_998409653_product_334571819.jpg
#   inflating: /content/data/data/train/image_train/image_998414119_product_85730182.jpg
#   inflating: /content/data/data/train/image_train/image_998426235_product_334571796.jpg
#   inflating: /content/data/data/train/image_train/image_998427095_product_334563990.jpg
#   inflating: /content/data/data/train/image_train/image_998427812_product_334572670.jpg
#   inflating: /content/data/data/train/image_train/image_998444151_product_334572136.jpg
#   inflating: /content/data/data/train/image_train/image_998444811_product_334571198.jpg
#   inflating: /content/data/data/train/image_train/image_998460419_product_334571441.jpg
#   inflating: /content/data/data/train/image_train/image_998473220_product_334573269.jpg
#   inflating: /content/data/data/train/image_train/image_998473662_product_334571979.jpg
#   inflating: /content/data/data/train/image_train/image_998474208_product_334574256.jpg
#   inflating: /content/data/data/train/image_train/image_998481634_product_334573703.jpg
#   inflating: /content/data/data/train/image_train/image_998481762_product_334575409.jpg
#   inflating: /content/data/data/train/image_train/image_998482088_product_334574408.jpg
#   inflating: /content/data/data/train/image_train/image_998482120_product_334573708.jpg
#   inflating: /content/data/data/train/image_train/image_998482821_product_334574999.jpg
#   inflating: /content/data/data/train/image_train/image_998482861_product_334574977.jpg
#   inflating: /content/data/data/train/image_train/image_998491305_product_334574039.jpg
#   inflating: /content/data/data/train/image_train/image_998491483_product_334573487.jpg
#   inflating: /content/data/data/train/image_train/image_998491856_product_334575154.jpg
#   inflating: /content/data/data/train/image_train/image_998492329_product_334575028.jpg
#   inflating: /content/data/data/train/image_train/image_998492635_product_334573582.jpg
#   inflating: /content/data/data/train/image_train/image_998500484_product_334575316.jpg
#   inflating: /content/data/data/train/image_train/image_998500493_product_334575463.jpg
#   inflating: /content/data/data/train/image_train/image_998501506_product_334575338.jpg
#   inflating: /content/data/data/train/image_train/image_998509951_product_334573299.jpg
#   inflating: /content/data/data/train/image_train/image_998509963_product_334573701.jpg
#   inflating: /content/data/data/train/image_train/image_998510724_product_334573427.jpg
#   inflating: /content/data/data/train/image_train/image_998513220_product_334573548.jpg
#   inflating: /content/data/data/train/image_train/image_998514592_product_86453025.jpg
#   inflating: /content/data/data/train/image_train/image_998554083_product_335713272.jpg
#   inflating: /content/data/data/train/image_train/image_998557914_product_52978414.jpg
#   inflating: /content/data/data/train/image_train/image_998606726_product_335707614.jpg
#   inflating: /content/data/data/train/image_train/image_998609044_product_335717210.jpg
#   inflating: /content/data/data/train/image_train/image_998692069_product_52949496.jpg
#   inflating: /content/data/data/train/image_train/image_998693417_product_67980064.jpg
#   inflating: /content/data/data/train/image_train/image_99877030_product_1949505.jpg
#   inflating: /content/data/data/train/image_train/image_998812657_product_85741209.jpg
#   inflating: /content/data/data/train/image_train/image_998825889_product_86424972.jpg
#   inflating: /content/data/data/train/image_train/image_998921862_product_337817561.jpg
#   inflating: /content/data/data/train/image_train/image_998924072_product_87095857.jpg
#   inflating: /content/data/data/train/image_train/image_998926770_product_52886189.jpg
#   inflating: /content/data/data/train/image_train/image_998936979_product_85894436.jpg
#   inflating: /content/data/data/train/image_train/image_998973920_product_338125974.jpg
#   inflating: /content/data/data/train/image_train/image_999052195_product_86578075.jpg
#   inflating: /content/data/data/train/image_train/image_999063264_product_86122280.jpg
#   inflating: /content/data/data/train/image_train/image_999076761_product_334123411.jpg
#   inflating: /content/data/data/train/image_train/image_999090548_product_19015533.jpg
#   inflating: /content/data/data/train/image_train/image_999101884_product_86972217.jpg
#   inflating: /content/data/data/train/image_train/image_999162172_product_339691065.jpg
#   inflating: /content/data/data/train/image_train/image_999213929_product_328202941.jpg
#   inflating: /content/data/data/train/image_train/image_999233488_product_339921567.jpg
#   inflating: /content/data/data/train/image_train/image_999332453_product_341654253.jpg
#   inflating: /content/data/data/train/image_train/image_999341997_product_339284924.jpg
#   inflating: /content/data/data/train/image_train/image_999345855_product_341609528.jpg
#   inflating: /content/data/data/train/image_train/image_999354463_product_341343715.jpg
#   inflating: /content/data/data/train/image_train/image_999355517_product_341869230.jpg
#   inflating: /content/data/data/train/image_train/image_99936530_product_390718.jpg
#   inflating: /content/data/data/train/image_train/image_999365772_product_342122194.jpg
#   inflating: /content/data/data/train/image_train/image_999368829_product_342122230.jpg
#   inflating: /content/data/data/train/image_train/image_999369243_product_342118963.jpg
#   inflating: /content/data/data/train/image_train/image_999369402_product_342118492.jpg
#   inflating: /content/data/data/train/image_train/image_999433208_product_343162078.jpg
#   inflating: /content/data/data/train/image_train/image_999447704_product_106331179.jpg
#   inflating: /content/data/data/train/image_train/image_999448764_product_333513717.jpg
#   inflating: /content/data/data/train/image_train/image_999505621_product_5429645.jpg
#   inflating: /content/data/data/train/image_train/image_999518368_product_339219787.jpg
#   inflating: /content/data/data/train/image_train/image_999523310_product_110331363.jpg
#   inflating: /content/data/data/train/image_train/image_999536214_product_343309101.jpg
#   inflating: /content/data/data/train/image_train/image_999551194_product_344088783.jpg
#   inflating: /content/data/data/train/image_train/image_999569766_product_343309099.jpg
#   inflating: /content/data/data/train/image_train/image_999581347_product_344240059.jpg
#   inflating: /content/data/data/train/image_train/image_999651682_product_67264781.jpg
#   inflating: /content/data/data/train/image_train/image_999689751_product_341551155.jpg
#   inflating: /content/data/data/train/image_train/image_999711923_product_345705186.jpg
#   inflating: /content/data/data/train/image_train/image_999731918_product_346014174.jpg
#   inflating: /content/data/data/train/image_train/image_999734080_product_346044445.jpg
#   inflating: /content/data/data/train/image_train/image_999795511_product_347242193.jpg
#   inflating: /content/data/data/train/image_train/image_999797209_product_347348753.jpg
#   inflating: /content/data/data/train/image_train/image_999810849_product_347242248.jpg
#   inflating: /content/data/data/train/image_train/image_999832391_product_348231336.jpg
#   inflating: /content/data/data/train/image_train/image_999863354_product_349647227.jpg
#   inflating: /content/data/data/train/image_train/image_999978542_product_347529201.jpg
#   inflating: /content/data/data/train/image_train/image_999988537_product_351615005.jpg
#   inflating: /content/data/data/train/X_train_update.csv
#   inflating: /content/data/data/train/Y_train_CVw08PX.csv
#   inflating: /content/data/import_data.py

# %%
import pandas as pd
import nltk
from bs4 import BeautifulSoup
import re
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
import pickle


class DataImporter:
    def __init__(self, filepath='/content/data/data'):
        self.filepath = filepath

    def load_data(self):
        data = pd.read_csv(f'{self.filepath}/X_train_update.csv')
        data['description'] = data['designation'] + str(data['description'])
        data = data.drop(['Unnamed: 0', 'designation'], axis=1)

        target = pd.read_csv(f'{self.filepath}/Y_train_CVw08PX.csv')
        target = target.drop(['Unnamed: 0'], axis=1)
        modalite_mapping = {modalite: i for i, modalite in enumerate(target['prdtypecode'].unique())}
        target['prdtypecode'] = target['prdtypecode'].replace(modalite_mapping)

        with open("/content/mapper.pkl", "wb") as fichier:
            pickle.dump(modalite_mapping, fichier)

        df = pd.concat([data, target], axis=1)

        return df

    def split_train_test(self, df, samples_per_class = 600):

        grouped_data = df.groupby('prdtypecode')

        X_train_samples = []
        X_test_samples = []

        for _, group in grouped_data:
            samples = group.sample(n=samples_per_class, random_state=42)
            X_train_samples.append(samples)

            remaining_samples = group.drop(samples.index)
            X_test_samples.append(remaining_samples)

        X_train = pd.concat(X_train_samples)
        X_test = pd.concat(X_test_samples)

        X_train = X_train.sample(frac=1, random_state=42).reset_index(drop=True)
        X_test = X_test.sample(frac=1, random_state=42).reset_index(drop=True)

        y_train = X_train['prdtypecode']
        X_train = X_train.drop(['prdtypecode'], axis=1)

        y_test = X_test['prdtypecode']
        X_test = X_test.drop(['prdtypecode'], axis=1)

        val_samples_per_class = 50

        grouped_data_test = pd.concat([X_test, y_test], axis=1).groupby('prdtypecode')

        X_val_samples = []
        y_val_samples = []

        for _, group in grouped_data_test:
            samples = group.sample(n=val_samples_per_class, random_state=42)
            X_val_samples.append(samples[['description', 'productid', 'imageid']])
            y_val_samples.append(samples['prdtypecode'])

        X_val = pd.concat(X_val_samples)
        y_val = pd.concat(y_val_samples)

        X_val = X_val.sample(frac=1, random_state=42).reset_index(drop=True)
        y_val = y_val.sample(frac=1, random_state=42).reset_index(drop=True)

        return X_train, X_val, X_test, y_train, y_val, y_test

# %%
class ImagePreprocessor:
    def __init__(self, filepath='/content/data/data'):
        self.filepath = filepath

    def preprocess_images_in_df(self, df):
        df['image_path'] =  f"{self.filepath}/image_train/image_" + df['imageid'].astype(str) + "_product_" + df['productid'].astype(str) + '.jpg'


class TextPreprocessor:
    def __init__(self):
        nltk.download('punkt')
        nltk.download('stopwords')
        nltk.download('wordnet')
        self.lemmatizer = WordNetLemmatizer()
        self.stop_words = set(stopwords.words('french'))  # Vous pouvez choisir une autre langue si nécessaire

    def preprocess_text(self, text):
        # Supprimer les balises HTML
        text = BeautifulSoup(text, 'html.parser').get_text()

        # Supprimer les caractères non alphabétiques
        text = re.sub(r'[^a-zA-Z]', ' ', text)

        # Tokenization
        words = word_tokenize(text.lower())

        # Suppression des stopwords et lemmatisation
        filtered_words = [self.lemmatizer.lemmatize(word) for word in words if word not in self.stop_words]

        return ' '.join(filtered_words[:10])

    def preprocess_text_in_df(self, df, columns):
        for column in columns:
            df[column] = df[column].apply(self.preprocess_text)

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import Input, Embedding, LSTM, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard

class TextLSTMModel:
    def __init__(self, max_words=10000, max_sequence_length=10):
        self.max_words = max_words
        self.max_sequence_length = max_sequence_length
        self.tokenizer = Tokenizer(num_words=max_words, oov_token='<OOV>')
        self.model = None

    def preprocess_and_fit(self, X_train, y_train, X_val, y_val):
        self.tokenizer.fit_on_texts(X_train['description'])

        tokenizer_config = self.tokenizer.to_json()
        with open('/content/tokenizer_config.json', 'w', encoding='utf-8') as json_file:
          json_file.write(tokenizer_config)

        train_sequences = self.tokenizer.texts_to_sequences(X_train['description'])
        train_padded_sequences = pad_sequences(train_sequences, maxlen=self.max_sequence_length, padding='post', truncating='post')

        val_sequences = self.tokenizer.texts_to_sequences(X_val['description'])
        val_padded_sequences = pad_sequences(val_sequences, maxlen=self.max_sequence_length, padding='post', truncating='post')

        text_input = Input(shape=(self.max_sequence_length,))
        embedding_layer = Embedding(input_dim=self.max_words, output_dim=128)(text_input)
        lstm_layer = LSTM(128)(embedding_layer)
        output = Dense(27, activation='softmax')(lstm_layer)

        self.model = Model(inputs=[text_input], outputs=output)

        self.model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

        lstm_callbacks = [ModelCheckpoint(filepath='/content/best_lstm_model.h5', save_best_only=True),  # Enregistre le meilleur modèle
        EarlyStopping(patience=3, restore_best_weights=True),  # Arrête l'entraînement si la performance ne s'améliore pas
        TensorBoard(log_dir='/content/logs')  # Enregistre les journaux pour TensorBoard
        ]

        self.model.fit(
            [train_padded_sequences],
            tf.keras.utils.to_categorical(y_train, num_classes=27),
            epochs=100,
            batch_size=32,
            validation_data=([val_padded_sequences], tf.keras.utils.to_categorical(y_val, num_classes=27)),
            callbacks=lstm_callbacks
        )

# %%
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.layers import Input, Dense, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard
import pandas as pd

class ImageVGG16Model:
    def __init__(self):
        self.model = None

    def preprocess_and_fit(self, X_train, y_train, X_val, y_val):
        # Paramètres
        batch_size = 32
        num_classes = 27

        df_train = pd.concat([X_train, y_train.astype(str)], axis=1)
        df_val = pd.concat([X_val, y_val.astype(str)], axis=1)

        # Créer un générateur d'images pour le set d'entraînement
        train_datagen = ImageDataGenerator()  # Normalisation des valeurs de pixel
        train_generator = train_datagen.flow_from_dataframe(
            dataframe=df_train,
            x_col='image_path',
            y_col='prdtypecode',
            target_size=(224, 224),  # Adapter à la taille d'entrée de VGG16
            batch_size=batch_size,
            class_mode='categorical',  # Utilisez 'categorical' pour les entiers encodés en one-hot
            shuffle=True
        )

        # Créer un générateur d'images pour le set de validation
        val_datagen = ImageDataGenerator()  # Normalisation des valeurs de pixel
        val_generator = val_datagen.flow_from_dataframe(
            dataframe=df_val,
            x_col='image_path',
            y_col='prdtypecode',
            target_size=(224, 224),
            batch_size=batch_size,
            class_mode='categorical',
            shuffle=False  # Pas de mélange pour le set de validation
        )

        image_input = Input(shape=(224, 224, 3))  # Adjust input shape according to your images

        vgg16_base = VGG16(include_top=False, weights='imagenet', input_tensor=image_input)

        x = vgg16_base.output
        x = Flatten()(x)
        x = Dense(256, activation='relu')(x)  # Add some additional layers if needed
        output = Dense(num_classes, activation='softmax')(x)

        self.model = Model(inputs=vgg16_base.input, outputs=output)

        for layer in vgg16_base.layers:
            layer.trainable = False

        self.model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

        vgg_callbacks = [ModelCheckpoint(filepath='/content/best_vgg16_model.h5', save_best_only=True),  # Enregistre le meilleur modèle
        EarlyStopping(patience=3, restore_best_weights=True),  # Arrête l'entraînement si la performance ne s'améliore pas
        TensorBoard(log_dir='/content/logs')  # Enregistre les journaux pour TensorBoard
        ]

        self.model.fit(
            train_generator,
            epochs=100,
            validation_data=val_generator,
            callbacks=vgg_callbacks
        )

# %%
import pandas as pd
from sklearn.utils import resample
import numpy as np
from tensorflow.keras.preprocessing.sequence import pad_sequences
import tensorflow as tf
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras.preprocessing.image import img_to_array, load_img
from sklearn.metrics import accuracy_score
import numpy as np

class concatenate:
    def __init__(self, tokenizer, lstm, vgg16):
        self.tokenizer = tokenizer
        self.lstm = lstm
        self.vgg16 = vgg16

    def preprocess_image(self, image_path, target_size):
        img = load_img(image_path, target_size=target_size)
        img_array = img_to_array(img)
        img_array = preprocess_input(img_array)
        return img_array

    def predict(self, X_train, y_train, new_samples_per_class = 50, max_sequence_length = 10):
        num_classes = 27

        new_X_train = pd.DataFrame(columns=X_train.columns)
        new_y_train = pd.DataFrame(columns=[0])  # Créez la structure pour les étiquettes

        # Boucle à travers chaque classe
        for class_label in range(num_classes):
            # Indices des échantillons appartenant à la classe actuelle
            indices = np.where(y_train == class_label)[0]

            # Sous-échantillonnage aléatoire pour sélectionner 'new_samples_per_class' échantillons
            sampled_indices = resample(indices, n_samples=new_samples_per_class, replace=False, random_state=42)

            # Ajout des échantillons sous-échantillonnés et de leurs étiquettes aux DataFrames
            new_X_train = pd.concat([new_X_train, X_train.loc[sampled_indices]])
            new_y_train = pd.concat([new_y_train, y_train.loc[sampled_indices]])

        # Réinitialiser les index des DataFrames
        new_X_train = new_X_train.reset_index(drop=True)
        new_y_train = new_y_train.reset_index(drop=True)
        new_y_train = new_y_train.values.reshape(1350).astype('int')

        # Charger les modèles préalablement sauvegardés
        tokenizer = self.tokenizer
        lstm_model = self.lstm
        vgg16_model = self.vgg16

        train_sequences = tokenizer.texts_to_sequences(new_X_train['description'])
        train_padded_sequences = pad_sequences(train_sequences, maxlen=10, padding='post', truncating='post')

        # Paramètres pour le prétraitement des images
        target_size = (224, 224, 3)  # Taille cible pour le modèle VGG16, ajustez selon vos besoins

        images_train = new_X_train['image_path'].apply(lambda x: self.preprocess_image(x, target_size))

        images_train = tf.convert_to_tensor(images_train.tolist(), dtype=tf.float32)

        lstm_proba = lstm_model.predict([train_padded_sequences])

        vgg16_proba = vgg16_model.predict([images_train])

        return lstm_proba, vgg16_proba, new_y_train

    def optimize(self, lstm_proba, vgg16_proba, y_train):
        # Recherche des poids optimaux en utilisant la validation croisée
        best_weights = None
        best_accuracy = 0.0

        for lstm_weight in np.linspace(0, 1, 101):  # Essayer différents poids pour LSTM
            vgg16_weight = 1.0 - lstm_weight  # Le poids total doit être égal à 1

            combined_predictions = (lstm_weight * lstm_proba) + (vgg16_weight * vgg16_proba)
            final_predictions = np.argmax(combined_predictions, axis=1)
            accuracy = accuracy_score(y_train, final_predictions)

            if accuracy > best_accuracy:
                best_accuracy = accuracy
                best_weights = (lstm_weight, vgg16_weight)

        return best_weights

# %%
import tensorflow as tf
from tensorflow import keras
import json


data_importer = DataImporter()
df = data_importer.load_data()
X_train, X_val, _, y_train, y_val, _ = data_importer.split_train_test(df)

# Preprocess text and images
text_preprocessor = TextPreprocessor()
image_preprocessor = ImagePreprocessor()
text_preprocessor.preprocess_text_in_df(X_train, columns=['description'])
text_preprocessor.preprocess_text_in_df(X_val, columns=['description'])
image_preprocessor.preprocess_images_in_df(X_train)
image_preprocessor.preprocess_images_in_df(X_val)

# Train LSTM model
text_lstm_model = TextLSTMModel()
text_lstm_model.preprocess_and_fit(X_train, y_train, X_val, y_val)

# Train VGG16 model
image_vgg16_model = ImageVGG16Model()
image_vgg16_model.preprocess_and_fit(X_train, y_train, X_val, y_val)

with open('/content/tokenizer_config.json', 'r', encoding='utf-8') as json_file:
    tokenizer_config = json_file.read()
tokenizer = tf.keras.preprocessing.text.tokenizer_from_json(
    tokenizer_config
)
lstm = keras.models.load_model('/content/best_lstm_model.h5')
vgg16 = keras.models.load_model('/content/best_vgg16_model.h5')

model_concatenate = concatenate(tokenizer, lstm, vgg16)
lstm_proba, vgg16_proba, new_y_train = model_concatenate.predict(X_train, y_train)
best_weights = model_concatenate.optimize(lstm_proba, vgg16_proba, new_y_train)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# Epoch 1/100
# 507/507 [==============================] - 28s 39ms/step - loss: 1.9187 - accuracy: 0.4451 - val_loss: 1.3015 - val_accuracy: 0.6200
# Epoch 2/100
#   1/507 [..............................] - ETA: 7s - loss: 1.1437 - accuracy: 0.6562
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 507/507 [==============================] - 5s 10ms/step - loss: 0.8892 - accuracy: 0.7405 - val_loss: 1.1267 - val_accuracy: 0.6800
# Epoch 3/100
# 507/507 [==============================] - 4s 9ms/step - loss: 0.5318 - accuracy: 0.8441 - val_loss: 1.1642 - val_accuracy: 0.6859
# Epoch 4/100
# 507/507 [==============================] - 4s 8ms/step - loss: 0.3535 - accuracy: 0.8945 - val_loss: 1.2644 - val_accuracy: 0.6867
# Epoch 5/100
# 507/507 [==============================] - 4s 8ms/step - loss: 0.2549 - accuracy: 0.9243 - val_loss: 1.3555 - val_accuracy: 0.6741
# Found 16200 validated image filenames belonging to 27 classes.
# Found 1350 validated image filenames belonging to 27 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 3s 0us/step
# Epoch 1/100
# 507/507 [==============================] - ETA: 0s - loss: 4.4088 - accuracy: 0.2088
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 507/507 [==============================] - 114s 207ms/step - loss: 4.4088 - accuracy: 0.2088 - val_loss: 2.8018 - val_accuracy: 0.2222
# Epoch 2/100
# 507/507 [==============================] - 89s 175ms/step - loss: 2.5944 - accuracy: 0.2902 - val_loss: 2.6305 - val_accuracy: 0.2696
# Epoch 3/100
# 507/507 [==============================] - 87s 171ms/step - loss: 2.3780 - accuracy: 0.3409 - val_loss: 2.5959 - val_accuracy: 0.3185
# Epoch 4/100
# 507/507 [==============================] - 87s 172ms/step - loss: 2.1496 - accuracy: 0.3855 - val_loss: 2.5896 - val_accuracy: 0.3400
# Epoch 5/100
# 507/507 [==============================] - 87s 172ms/step - loss: 2.0160 - accuracy: 0.4114 - val_loss: 2.5019 - val_accuracy: 0.3437
# Epoch 6/100
# 507/507 [==============================] - 90s 178ms/step - loss: 1.9285 - accuracy: 0.4278 - val_loss: 2.5293 - val_accuracy: 0.3474
# Epoch 7/100
# 507/507 [==============================] - 86s 169ms/step - loss: 1.8449 - accuracy: 0.4480 - val_loss: 2.5790 - val_accuracy: 0.3496
# Epoch 8/100
# 507/507 [==============================] - 87s 172ms/step - loss: 1.8032 - accuracy: 0.4615 - val_loss: 2.5231 - val_accuracy: 0.3615
# 43/43 [==============================] - 1s 2ms/step
# 43/43 [==============================] - 5s 118ms/step

# %%
with open("/content/best_weights.pkl", "wb") as fichier:
    pickle.dump(best_weights, fichier)

num_classes = 27

proba_lstm = keras.layers.Input(shape=(num_classes,))
proba_vgg16 = keras.layers.Input(shape=(num_classes,))

weighted_proba = keras.layers.Lambda(lambda x: best_weights[0] * x[0] + best_weights[1] * x[1])([proba_lstm, proba_vgg16])

concatenate_model = keras.models.Model(inputs=[proba_lstm, proba_vgg16], outputs=weighted_proba)

# Enregistrer le modèle au format h5
concatenate_model.save('/content/concatenate.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
